# %% [markdown]
# # 19CSE305 ML - Pandas Exercise Questions - 23rd Aug 2023

# %% [markdown]
# ### Task 1. Go to https://www.kaggle.com/openfoodfacts/world-food-facts/data

# %% [markdown]
# ### Task 2. Download the dataset to your computer and unzip it.

# %% [markdown]
# ### Task 3. Use the tsv file and assign it to a dataframe called food

# %%
import pandas as pd

# %%
food = pd.read_csv('en.openfoodfacts.org.products.tsv',delimiter='\t')
# Out:
# /var/folders/0b/gfxxt85j7gd7kywb8_4gnmf00000gn/T/ipykernel_10741/4265466718.py:1: DtypeWarning: Columns (0,3,5,19,20,24,25,26,27,28,36,37,38,39,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   food = pd.read_csv('en.openfoodfacts.org.products.tsv',delimiter='\t')

# %% [markdown]
# ### Task 4. See the first 5 entries

# %%
food.head(5)
# Out:
#     code                                                url  \
# 0   3087  http://world-en.openfoodfacts.org/product/0000...
# 1   4530  http://world-en.openfoodfacts.org/product/0000...
# 2   4559  http://world-en.openfoodfacts.org/product/0000...
# 3  16087  http://world-en.openfoodfacts.org/product/0000...
# 4  16094  http://world-en.openfoodfacts.org/product/0000...
#
#                       creator   created_t      created_datetime  \
# 0  openfoodfacts-contributors  1474103866  2016-09-17T09:17:46Z
# 1             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 2             usda-ndb-import  1489069957  2017-03-09T14:32:37Z
# 3             usda-ndb-import  1489055731  2017-03-09T10:35:31Z
# 4             usda-ndb-import  1489055653  2017-03-09T10:34:13Z
#
#   last_modified_t last_modified_datetime                    product_name  \
# 0      1474103893   2016-09-17T09:18:13Z              Farine de blé noir
# 1      1489069957   2017-03-09T14:32:37Z  Banana Chips Sweetened (Whole)
# 2      1489069957   2017-03-09T14:32:37Z                         Peanuts
# 3      1489055731   2017-03-09T10:35:31Z          Organic Salted Nut Mix
# 4      1489055653   2017-03-09T10:34:13Z                 Organic Polenta
#
#   generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 0          NaN      1kg  ...                         NaN
# 1          NaN      NaN  ...                         NaN
# 2          NaN      NaN  ...                         NaN
# 3          NaN      NaN  ...                         NaN
# 4          NaN      NaN  ...                         NaN
#
#   fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 0                                  NaN                              NaN
# 1                                  NaN                              NaN
# 2                                  NaN                              NaN
# 3                                  NaN                              NaN
# 4                                  NaN                              NaN
#
#   cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 0        NaN             NaN                   NaN                     NaN
# 1        NaN             NaN                   NaN                    14.0
# 2        NaN             NaN                   NaN                     0.0
# 3        NaN             NaN                   NaN                    12.0
# 4        NaN             NaN                   NaN                     NaN
#
#   nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 0                     NaN                 NaN                 NaN
# 1                    14.0                 NaN                 NaN
# 2                     0.0                 NaN                 NaN
# 3                    12.0                 NaN                 NaN
# 4                     NaN                 NaN                 NaN
#
# [5 rows x 163 columns]

# %% [markdown]
# ### Task 5. What is the number of observations in the dataset?

# %%
print(food.shape[0])
# Out:
# 356027

# %% [markdown]
# ### Task 6. What is the number of columns in the dataset?

# %%
print(food.shape[1])
# Out:
# 163

# %% [markdown]
# ### Task 7. Print the name of all the columns.

# %%
food.columns
# Out:
# Index(['code', 'url', 'creator', 'created_t', 'created_datetime',
#        'last_modified_t', 'last_modified_datetime', 'product_name',
#        'generic_name', 'quantity',
#        ...
#        'fruits-vegetables-nuts_100g', 'fruits-vegetables-nuts-estimate_100g',
#        'collagen-meat-protein-ratio_100g', 'cocoa_100g', 'chlorophyl_100g',
#        'carbon-footprint_100g', 'nutrition-score-fr_100g',
#        'nutrition-score-uk_100g', 'glycemic-index_100g',
#        'water-hardness_100g'],
#       dtype='object', length=163)

# %% [markdown]
# ### Task 8. What is the name of 105th column?

# %%
food.columns[104]
# Out:
# '-glucose_100g'

# %% [markdown]
# ### Task 9. What is the type of the observations of the 105th column?

# %%
food.dtypes[104]
# Out:
# dtype('float64')

# %% [markdown]
# ### Task 10. How is the dataset indexed?

# %%
food.index
# Out:
# RangeIndex(start=0, stop=356027, step=1)

# %% [markdown]
# ### Task 11. What is the product name of the 19th observation?

# %%
food["product_name"][18]
# Out:
# 'Lotus Organic Brown Jasmine Rice'

# %% [markdown]
# ### Task 12. How many columns in the dataset tend to have null values?

# %%
nc = food.isnull().sum()
print(nc[nc>0].count())
# Out:
# 161

# %% [markdown]
# ### Task 13. Find the number of null values present under each column?

# %%
food.isnull().sum()
# Out:
# code                           26
# url                            26
# creator                         3
# created_t                       3
# created_datetime               10
#                             ...
# carbon-footprint_100g      355749
# nutrition-score-fr_100g    101171
# nutrition-score-uk_100g    101171
# glycemic-index_100g        356027
# water-hardness_100g        356027
# Length: 163, dtype: int64

# %% [markdown]
# ### Task 14. Create a dictionary with keys to be column names in the dataset and values to number of null values under each column. Print the dictionary by iterating through its elements using a for loop.

# %%
d = {}
nc = food.isnull().sum()
for i in range(food.shape[1]):
    d[food.columns[i]] = nc[i]
print(d)
# Out:
# {'code': 26, 'url': 26, 'creator': 3, 'created_t': 3, 'created_datetime': 10, 'last_modified_t': 0, 'last_modified_datetime': 0, 'product_name': 17512, 'generic_name': 298313, 'quantity': 236742, 'packaging': 266068, 'packaging_tags': 266068, 'brands': 29050, 'brands_tags': 29070, 'categories': 252728, 'categories_tags': 252752, 'categories_en': 252726, 'origins': 330977, 'origins_tags': 331015, 'manufacturing_places': 314019, 'manufacturing_places_tags': 314026, 'labels': 296929, 'labels_tags': 296849, 'labels_en': 296823, 'emb_codes': 323537, 'emb_codes_tags': 323541, 'first_packaging_code_geo': 335155, 'cities': 356001, 'cities_tags': 333525, 'purchase_places': 289462, 'stores': 298326, 'countries': 275, 'countries_tags': 275, 'countries_en': 275, 'ingredients_text': 72134, 'allergens': 318851, 'allergens_en': 356007, 'traces': 327606, 'traces_tags': 327633, 'traces_en': 327607, 'serving_size': 139406, 'no_nutriments': 356027, 'additives_n': 72160, 'additives': 72202, 'additives_tags': 185838, 'additives_en': 185838, 'ingredients_from_palm_oil_n': 72160, 'ingredients_from_palm_oil': 356027, 'ingredients_from_palm_oil_tags': 349455, 'ingredients_that_may_be_from_palm_oil_n': 72160, 'ingredients_that_may_be_from_palm_oil': 356027, 'ingredients_that_may_be_from_palm_oil_tags': 341699, 'nutrition_grade_uk': 356027, 'nutrition_grade_fr': 101171, 'pnns_groups_1': 227021, 'pnns_groups_2': 223338, 'states': 52, 'states_tags': 52, 'states_en': 52, 'main_category': 252778, 'main_category_en': 252778, 'image_url': 280302, 'image_small_url': 280302, 'energy_100g': 60660, 'energy-from-fat_100g': 355158, 'fat_100g': 76530, 'saturated-fat_100g': 92204, '-butyric-acid_100g': 356027, '-caproic-acid_100g': 356027, '-caprylic-acid_100g': 356026, '-capric-acid_100g': 356025, '-lauric-acid_100g': 356023, '-myristic-acid_100g': 356026, '-palmitic-acid_100g': 356026, '-stearic-acid_100g': 356026, '-arachidic-acid_100g': 356000, '-behenic-acid_100g': 356001, '-lignoceric-acid_100g': 356027, '-cerotic-acid_100g': 356027, '-montanic-acid_100g': 356026, '-melissic-acid_100g': 356027, 'monounsaturated-fat_100g': 332987, 'polyunsaturated-fat_100g': 332952, 'omega-3-fat_100g': 355089, '-alpha-linolenic-acid_100g': 355826, '-eicosapentaenoic-acid_100g': 355984, '-docosahexaenoic-acid_100g': 355938, 'omega-6-fat_100g': 355820, '-linoleic-acid_100g': 355868, '-arachidonic-acid_100g': 356018, '-gamma-linolenic-acid_100g': 356000, '-dihomo-gamma-linolenic-acid_100g': 356001, 'omega-9-fat_100g': 356002, '-oleic-acid_100g': 356012, '-elaidic-acid_100g': 356027, '-gondoic-acid_100g': 356011, '-mead-acid_100g': 356027, '-erucic-acid_100g': 356027, '-nervonic-acid_100g': 356027, 'trans-fat_100g': 212584, 'cholesterol_100g': 211857, 'carbohydrates_100g': 76807, 'sugars_100g': 76841, '-sucrose_100g': 355942, '-glucose_100g': 355995, '-fructose_100g': 355983, '-lactose_100g': 355749, '-maltose_100g': 356021, '-maltodextrins_100g': 356016, 'starch_100g': 355736, 'polyols_100g': 355576, 'fiber_100g': 135344, 'proteins_100g': 61866, 'casein_100g': 355998, 'serum-proteins_100g': 356010, 'nucleotides_100g': 356018, 'salt_100g': 66288, 'sodium_100g': 66333, 'alcohol_100g': 351450, 'vitamin-a_100g': 218321, 'beta-carotene_100g': 355992, 'vitamin-d_100g': 348820, 'vitamin-e_100g': 354555, 'vitamin-k_100g': 355097, 'vitamin-c_100g': 214967, 'vitamin-b1_100g': 344750, 'vitamin-b2_100g': 345102, 'vitamin-pp_100g': 344196, 'vitamin-b6_100g': 349130, 'vitamin-b9_100g': 350697, 'folates_100g': 352981, 'vitamin-b12_100g': 350637, 'biotin_100g': 355696, 'pantothenic-acid_100g': 353476, 'silica_100g': 355954, 'bicarbonate_100g': 355928, 'potassium_100g': 331179, 'chloride_100g': 355829, 'calcium_100g': 214510, 'phosphorus_100g': 350089, 'iron_100g': 215367, 'magnesium_100g': 349635, 'zinc_100g': 352063, 'copper_100g': 353905, 'manganese_100g': 354388, 'fluoride_100g': 355928, 'selenium_100g': 354846, 'chromium_100g': 356004, 'molybdenum_100g': 356007, 'iodine_100g': 355739, 'caffein ...

# %% [markdown]
# ### Task 15. Display the values associated with all columns from row 108 to 208?

# %%
food.iloc[108:209,:]
# Out:
#          code                                                url  \
# 108     36252  http://world-en.openfoodfacts.org/product/0000...
# 109     36269  http://world-en.openfoodfacts.org/product/0000...
# 110     36276  http://world-en.openfoodfacts.org/product/0000...
# 111     36986  http://world-en.openfoodfacts.org/product/0000...
# 112     38058  http://world-en.openfoodfacts.org/product/0000...
# ..        ...                                                ...
# 204  20043087  http://world-en.openfoodfacts.org/product/0000...
# 205  20043124  http://world-en.openfoodfacts.org/product/0000...
# 206  20043131  http://world-en.openfoodfacts.org/product/0000...
# 207  20044015  http://world-en.openfoodfacts.org/product/0000...
# 208  20044480  http://world-en.openfoodfacts.org/product/0000...
#
#              creator   created_t      created_datetime last_modified_t  \
# 108          tacinte  1422221701  2015-01-25T21:35:01Z      1494824741
# 109  usda-ndb-import  1489055651  2017-03-09T10:34:11Z      1489055651
# 110  usda-ndb-import  1489055678  2017-03-09T10:34:38Z      1489055678
# 111  usda-ndb-import  1489055649  2017-03-09T10:34:09Z      1489055649
# 112  usda-ndb-import  1489055651  2017-03-09T10:34:11Z      1489055651
# ..               ...         ...                   ...             ...
# 204  usda-ndb-import  1489135780  2017-03-10T08:49:40Z      1489135780
# 205  usda-ndb-import  1489133902  2017-03-10T08:18:22Z      1489133902
# 206  usda-ndb-import  1489133434  2017-03-10T08:10:34Z      1489133434
# 207  usda-ndb-import  1489133902  2017-03-10T08:18:22Z      1489133902
# 208  usda-ndb-import  1489133434  2017-03-10T08:10:34Z      1489133434
#
#     last_modified_datetime                             product_name  \
# 108   2017-05-15T05:05:41Z                           Lion Peanut x2
# 109   2017-03-09T10:34:11Z  Milk Chocolate Peanut Butter Malt Balls
# 110   2017-03-09T10:34:38Z              Organic Tamari Pumpkin Seed
# 111   2017-03-09T10:34:09Z                          Yogurt Pretzels
# 112   2017-03-09T10:34:11Z                     Organic Kamut Flakes
# ..                     ...                                      ...
# 204   2017-03-10T08:49:40Z                                  Biscuit
# 205   2017-03-10T08:18:22Z                    Oatmeal Raisin Cookie
# 206   2017-03-10T08:10:34Z                       Sliced Plain Bagel
# 207   2017-03-10T08:18:22Z                                    Scone
# 208   2017-03-10T08:10:34Z                   Belgian Vanilla Waffle
#
#     generic_name quantity  ... fruits-vegetables-nuts_100g  \
# 108          NaN      NaN  ...                         NaN
# 109          NaN      NaN  ...                         NaN
# 110          NaN      NaN  ...                         NaN
# 111          NaN      NaN  ...                         NaN
# 112          NaN      NaN  ...                         NaN
# ..           ...      ...  ...                         ...
# 204          NaN      NaN  ...                         NaN
# 205          NaN      NaN  ...                         NaN
# 206          NaN      NaN  ...                         NaN
# 207          NaN      NaN  ...                         NaN
# 208          NaN      NaN  ...                         NaN
#
#     fruits-vegetables-nuts-estimate_100g collagen-meat-protein-ratio_100g  \
# 108                                  NaN                              NaN
# 109                                  NaN                              NaN
# 110                                  NaN                              NaN
# 111                                  NaN                              NaN
# 112                                  NaN                              NaN
# ..                                   ...                              ...
# 204                                  NaN                              NaN
# 205                                  NaN                              NaN
# 206                                  NaN                              NaN
# 207                                  NaN                              NaN
# 208                                  NaN                              NaN
#
#     cocoa_100g chlorophyl_100g carbon-footprint_100g nutrition-score-fr_100g  \
# 108        NaN             NaN                   NaN                     NaN
# 109        NaN             NaN                   NaN                    23.0
# 110        NaN             NaN                   NaN                    15.0
# 111        NaN             NaN                   NaN                    30.0
# 112        NaN             NaN                   NaN                     NaN
# ..         ...             ...                   ...                     ...
# 204        NaN             NaN                   NaN                    18.0
# 205        NaN             NaN                   NaN                    21.0
# 206        NaN             NaN                   NaN                     2.0
# 207        NaN             NaN                   NaN                    19.0
# 208        NaN             NaN                   NaN                    25.0
#
#     nutrition-score-uk_100g glycemic-index_100g water-hardness_100g
# 108                     NaN                 NaN                 NaN
# 109                    23.0                 NaN                 NaN
# 110                    15.0                 NaN                 NaN
# 111                    30.0                 NaN                 NaN
# 112                     NaN                 NaN                 NaN
# ..                      ...                 ...                 ...
# 204                    18.0                 NaN                 NaN
# 205                    21.0                 NaN                 NaN
# 206                     2.0                 NaN                 NaN
# 207                    19.0                 NaN                 NaN
# 208                    25.0                 NaN                 NaN
#
# [101 rows x 163 columns]
